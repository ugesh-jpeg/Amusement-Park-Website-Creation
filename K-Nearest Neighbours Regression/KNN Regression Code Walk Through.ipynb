# %% [markdown]
# <a href="https://colab.research.google.com/github/ugesh-jpeg/Amusement-Park-Website-Creation/blob/main/K-Nearest%20Neighbours%20Regression/KNN%20Regression%20Code%20Walk%20Through.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
X_train = np.array( [ [0.377, 2.222],
                      [0.933, 0.566],
                      [1.525, 2.854],
                      [1.691, 1.048],
                      [2.173, 2.518],
                      [2.573, 2.298],
                      [2.687, 3.891],
                      [2.959, 2.108],
                      [3.340, 1.234],
                      [3.465, 3.062] ] )

y_train = np.array( [1, 3, 4, 4, 5, 4, 6, 5, 4, 6] )

# %%
X_train
# Out:
# array([[0.377, 2.222],
#        [0.933, 0.566],
#        [1.525, 2.854],
#        [1.691, 1.048],
#        [2.173, 2.518],
#        [2.573, 2.298],
#        [2.687, 3.891],
#        [2.959, 2.108],
#        [3.34 , 1.234],
#        [3.465, 3.062]])

# %%
X_train.shape
# Out:
# (10, 2)

# %%
y_train
# Out:
# array([1, 3, 4, 4, 5, 4, 6, 5, 4, 6])

# %%
import matplotlib.pyplot as plt

plt.scatter(X_train[:,0], X_train[:,1], c=y_train, cmap="winter")
plt.axis([0, 5, 0, 5])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.grid()
plt.show()

# %%
# Test data point
X_test = np.array([[2, 2]])

# %%
X_test
# Out:
# array([[2, 2]])

# %%
from sklearn.metrics import pairwise_distances

# %%
d = pairwise_distances(X_test, X_train).ravel()
d
# Out:
# array([1.63811263, 1.78741293, 0.97721083, 1.0008921 , 0.54612544,
#        0.64585834, 2.01192694, 0.96506217, 1.54348826, 1.80943886])

# %%
np.sort(d)
# Out:
# array([0.54612544, 0.64585834, 0.96506217, 0.97721083, 1.0008921 ,
#        1.54348826, 1.63811263, 1.78741293, 1.80943886, 2.01192694])

# %%
np.sort(d)[:5].mean()
# Out:
# np.float64(0.8270297780197959)

# %%
# returns the index
J = np.argsort(d)
J
# Out:
# array([4, 5, 7, 2, 3, 8, 0, 1, 9, 6])

# %%
J = np.argsort(d)[:5]
J
# Out:
# array([4, 5, 7, 2, 3])

# %%
 y_train[J]
# Out:
# array([5, 4, 5, 4, 4])

# %%
pred = y_train[J].mean()
pred
# Out:
# np.float64(4.2)
